# %% [markdown]
# <a href="https://colab.research.google.com/github/SandeepValaVala/FFML-ASSIGNMENT-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-15 09:43:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   253MB/s    in 0.3s
#
# 2023-06-15 09:43:39 (253 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3435 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1778   1606.05320v2  As deep neural networks continue to revolution...  stat
# 7669   1802.07176v1  We consider the problem of active coarse ranki...    cs
# 6724   1705.08564v1  It is oftentimes impossible to understand how ...    cs
# 19088   1304.1096v1  In previous work (Fertig and Breese, 1989; Fer...    cs
# 10566   1303.5685v2  We develop a new model and algorithms for mach...  stat
# ...             ...                                                ...   ...
# 21539   0912.3301v1  We study losses for binary classification and ...  stat
# 408    1711.09055v1  A growing field in robotics and Artificial Int...    cs
# 27687  1704.02581v2  Recently, skeleton based action recognition ga...    cs
# 22941  1711.05363v1  A nonparametric family of conditional distribu...  stat
# 3165   1505.00853v2  In this paper we investigate the performance o...    cs
#
#                                                    title  year  \
# 1778   Increasing the Interpretability of Recurrent N...  2016
# 7669                Adaptive Sampling for Coarse Ranking  2018
# 6724   Towards Interrogating Discriminative Machine L...  2017
# 19088   Decision Making with Interval Influence Diagrams  2013
# 10566  Sparse Factor Analysis for Learning and Conten...  2013
# ...                                                  ...   ...
# 21539                            Composite Binary Losses  2009
# 408    Interactive Robot Learning of Gestures, Langua...  2017
# 27687  Modeling Temporal Dynamics and Spatial Configu...  2017
# 22941              Kernel Conditional Exponential Family  2017
# 3165   Empirical Evaluation of Rectified Activations ...  2015
#
#                                                 keywords
# 1778   [revolutionize, application, increasing, under...
# 7669   [according, specified, adaptively, distributio...
# 6724   [oftentimes, impossible, understand, technical...
# 19088  [mechanism, performing, probabilistic, reasoni...
# 10566  [algorithms, analytics, knowledge, underlying,...
# ...                                                  ...
# 21539  [classification, probability, estimation, unde...
# 408    [artificial, intelligence, collaboration, effe...
# 27687  [recognition, popularity, effective, estimatio...
# 22941  [nonparametric, conditional, distributions, in...
# 3165   [investigate, performance, different, rectifie...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1778     [revolutionize, application, increasing, under...
# 7669     [according, specified, adaptively, distributio...
# 6724     [oftentimes, impossible, understand, technical...
# 19088    [mechanism, performing, probabilistic, reasoni...
# 10566    [algorithms, analytics, knowledge, underlying,...
#                                ...
# 8460     [probabilistic, estimates, distribution, archi...
# 19161    [artificial, intelligence, experience, experim...
# 5418     [framework, representations, statistical, tech...
# 34009    [interpreted, procedural, programming, represe...
# 21762    [comparisons, classical, neurological, clinici...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8810 words.
# Out of those 4600 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="30b57566-3b63-44a9-8f42-885276109207" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30b57566-3b63-44a9-8f42-885276109207")) {                    Plotly.newPlot(                        "30b57566-3b63-44a9-8f42-885276109207",                        [{"x":["predictions","combining","combinations","recognition","information","narrowing","interpretability","recurrent","interpretable","performance","transparent","complementary","distributions","application","translation","understandable","increasing","significantly","experiments","distribution","advantage","approximate","applications","underlying","efficient","specified","involving","computationally","parametric","complexity","synthetic","comparison","according","adaptively","dependent","algorithm","oftentimes","vulnerabilities","explanations","discriminative","individual","explaining","technique","understand","regression","demonstrate","different","approaches","impossible","decisions","technical","outperforms","approximation","imprecision","investigated","probabilistic","admissible","performing","associated","alternatives","sensitivity","probability","mechanism","imprecise","transformations","probabilities","incorporate","procedures","influence","reasoning","functions","procedure","dimensional","algorithms","relationships","likelihood","responses","analytics","dictionary","resulting","connection","difficulty","collection","leveraging","represents","estimated","intrinsic","understanding","estimation","facilitate","questions","independent","especially","observation","knowledge","educational","selection","accordingly","formulation","selecting","quadratic","piecewise","minimizing","computational","sequential","significant","criterion","optimization","incorporating","inappropriate","contribution","structure","capabilities","furthermore","determine","developed","inference","simultaneously","statistical","predefine","incorporates","assigning","emotional","conditional","interests","stochastic","hierarchical","traditional","classical","retrieval","difficult","processing","necessarily","environments","outperform","empirical","counterpart","gradients","kronecker","efficiency","objective","unpenalized","validation","explained","concentration","asymptotic","generalization","estimators","penalized","estimates","parameters","difference","population","conditions","prediction","corresponding","perspective","simulations","inequalities","consistent","improvement","architectures","algorithmic","interesting","predictive","massively","accuracies","accelerate","discovery","transferability","innovation","underscore","framework","multitask","investigate","biological","synthesizes","measurements","contribute","additional","denoising","polynomials","chebyshev","properties","implemented","improving","important","demonstrated","sensitive","comprehensive","preserving","efficiently","operators","computing","constructed","supervised","providing","convergence","theoretical","illustrating"],"y":[88,123,38,384,704,0,13,141,19,870,6,48,135,242,119,6,110,288,609,227,86,105,420,98,421,48,39,103,41,208,139,135,99,22,66,804,1,4,16,102,134,17,264,69,105,511,759,439,19,65,38,260,126,3,51,164,6,90,103,31,39,168,117,6,39,58,75,25,57,133,206,125,165,554,75,62,29,15,51,148,46,43,73,46,47,46,48,151,199,43,66,126,115,68,358,7,173,10,86,51,26,23,41,289,67,249,54,286,59,9,89,346,47,173,61,175,200,111,176,2,38,15,13,114,17,121,112,178,111,112,148,289,16,81,93,131,17,31,2,158,171,0,47,12,13,13,108,17,2,63,251,56,62,130,232,119,66,42,7,90,153,111,55,61,58,6,18,19,58,2,4,0,558,8,143,42,5,53,23,100,42,8,2,200,101,97,344,100,54,55,54,140,59,165,47,204,88,106,134,3],"type":"bar"},{"x":["predictions","combining","combinations","recognition","in ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4600,), (4600, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Refined</span> <span style=''>Error</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>Several</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>studies</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>achievable</span> <span style='background-color:rgba(255, 0, 0, 0.351063829787234);'>guarantees</span> <span style=''>on</span> <span style=''>the</span> <span style=''>error</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>certain</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>refining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithmic</span> <span style=''>factors</span> <span style=''>Many</span> <span style=''>of</span> <span style=''>the</span> <span style=''>results</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>error</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>monotonic</span> <span style=''>error</span> <span style=''>regions</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>realizable</span> <span style=''>case</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>bounds</span> <span style=''>of</span> <span style=''>this</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>either</span> <span style=''>the</span> <span style=''>VC</span> <span style='background-color:rgba(255, 0, 0, 0.37823834196891193);'>dimension</span> <span style=''>or</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compression</span> <span style=''>size</span> <span style=''>This</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>also</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>several</span> <span style=''>new</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>error</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>general</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>refined</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CAL</span> <span style=''>active</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>local</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>discrete</span> <span style=''>loglinear</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>estimate</span> <span style=''>(mle)</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>When</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>there</span> <span style=''>are</span> <span style=''>many</span> <span style=''>zeros</span> <span style=''>in</span> <span style=''>the</span> <span style=''>contingency</span> <span style=''>table</span> <span style=''>and</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>may</span> <span style=''>not</span> <span style=''>exist</span> <span style=''>Fienberg</span> <span style=''>and</span> <span style=''>Rinaldo</span> <span style=''>(2012)</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>mle</span> <span style=''>does</span> <span style=''>not</span> <span style=''>exists</span> <span style=''>iff</span> <span style=''>the</span> <span style=''>data</span> <span style=''>vector</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>face</span> <span style=''>of</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style=''>marginal</span> <span style=''>cone</span> <span style=''>spanned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>rows</span> <span style=''>of</span> <span style=''>the</span> <span style=''>design</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identifying</span> <span style=''>these</span> <span style=''>faces</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>take</span> <span style=''>a</span> <span style=''>local</span> <span style=''>approach</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>one</span> <span style=''>such</span> <span style=''>face</span> <span style=''>albeit</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Metric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>adaptive</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>general</span> <span style=''>metric</span> <span style=''>spaces</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>bound</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.4782608695652174);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>metric</span> <span style=''>spaces</span> <span style=''>that</span> <span style=''>are</span> <span style=''>doubling</span> <span style=''>or</span> <span style=''>nearly</span> <span style=''>doubling</span> <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style=''>front</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>an</span> <span style=''>analogue</span> <span style=''>of</span> <span style=''>PCA</span> <span style=''>for</span> <span style=''>metric</span> <span style=''>spaces</span> <span style=''>namely</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style=''>datas</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.37823834196891193);'>dimension</span> <span style=''>which</span> <span style=''>is</span> <span style=''>often</span> <span style=''>much</span> <span style=''>lower</span> <span style=''>than</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.37823834196891193);'>dimension</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>the</span> <span style=''>dual</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>(1)</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>eg</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proximity</span> <span style=''>search</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>bounds</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayes</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Decoding</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertain</span> <span style=''>Digital</span> <span style=''>Receiver</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>symbol</span> <span style=''>and</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>a</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsynchronized</span> <span style=''>digital</span> <span style=''>receiver</span> <span style=''>It</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>primarily</span> <span style=''>extends</span> <span style=''>Quinn</span> <span style=''>2011</span> <span style=''>to</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>symbol</span> <span style=''>case</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayes</span> <span style=''>(VB)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>this</span> <span style=''>case</span> <span style=''>The</span> <span style=''>work</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>fully</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EM</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>current</span> <span style=''>turbo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synchronization</span> <span style=''>methods</span> <span style=''>since</span> <span style=''>it</span> <span style=''>induces</span> <span style=''>a</span> <span style=''>von</span> <span style=''>Mises</span> <span style=''>prior</span> <span style=''>on</span> <span style=''>the</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>phase</span> <span style=''>parmeter</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>we</span> <span style=''>achieve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>improved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>in</span> <span style=''>low</span> <span style=''>SNR</span> <span style=''>regimes</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>current</span> <span style=''>EM</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>As</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1306370794559771)
# 	processing (0.10343593414459556)
# 	architecture (0.0819613457408733)
# 	experimental (0.14030064423765212)
# 	segmentation (0.0733715103793844)
# 	information (0.25196850393700787)
# 	detection (0.13314244810307801)
# 	different (0.27165354330708663)
# 	convolutional (0.1385110952040086)
# 	recognition (0.13743736578382248)
#
# Some Statistics words are:
# 	statistical (0.14955134596211367)
# 	estimation (0.16201395812562314)
# 	stochastic (0.13409770687936193)
# 	variables (0.14356929212362912)
# 	theoretical (0.1465603190428714)
# 	algorithm (0.38883349950149554)
# 	distribution (0.1864406779661017)
# 	inference (0.19441674975074777)
# 	dimensional (0.1864406779661017)
# 	regression (0.17397806580259223)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c797db9e-0132-4734-ba26-520baa91072a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c797db9e-0132-4734-ba26-520baa91072a")) {                    Plotly.newPlot(                        "c797db9e-0132-4734-ba26-520baa91072a",                        [{"x":["predictions","combining","combinations","recognition","information","narrowing","interpretability","recurrent","interpretable","performance","transparent","complementary","distributions","application","translation","understandable","increasing","significantly","experiments","distribution","advantage","approximate","applications","underlying","efficient","specified","involving","computationally","parametric","complexity","synthetic","comparison","according","adaptively","dependent","algorithm","oftentimes","vulnerabilities","explanations","discriminative","individual","explaining","technique","understand","regression","demonstrate","different","approaches","impossible","decisions","technical","outperforms","approximation","imprecision","investigated","probabilistic","admissible","performing","associated","alternatives","sensitivity","probability","mechanism","imprecise","transformations","probabilities","incorporate","procedures","influence","reasoning","functions","procedure","dimensional","algorithms","relationships","likelihood","responses","analytics","dictionary","resulting","connection","difficulty","collection","leveraging","represents","estimated","intrinsic","understanding","estimation","facilitate","questions","independent","especially","observation","knowledge","educational","selection","accordingly","formulation","selecting","quadratic","piecewise","minimizing","computational","sequential","significant","criterion","optimization","incorporating","inappropriate","contribution","structure","capabilities","furthermore","determine","developed","inference","simultaneously","statistical","predefine","incorporates","assigning","emotional","conditional","interests","stochastic","hierarchical","traditional","classical","retrieval","difficult","processing","necessarily","environments","outperform","empirical","counterpart","gradients","kronecker","efficiency","objective","unpenalized","validation","explained","concentration","asymptotic","generalization","estimators","penalized","estimates","parameters","difference","population","conditions","prediction","corresponding","perspective","simulations","inequalities","consistent","improvement","architectures","algorithmic","interesting","predictive","massively","accuracies","accelerate","discovery","transferability","innovation","underscore","framework","multitask","investigate","biological","synthesizes","measurements","contribute","additional","denoising","polynomials","chebyshev","properties","implemented","improving","important","demonstrated","sensitive","comprehensive","preserving","efficiently","operators","computing","constructed","supervised","providing","convergence","theoretical","illustrating","depending","manageable","sometimes","controversial","monotonous","circumstances","logarithmic","principle","classification","variations","synthesis","discrimination","practical","resolution","resolutions","illumination","resultant","differently","available","kernelize","formulate","classifying","linearity","effectiveness","literature","competitive","challenging","modifying","impractical","convolutional","development","extremely","experiment","diagnosis","distorted","thousands","interpreted","unsupervised","undergoing","potential","diagnostic","localization","observers","activations","histological","visualization","opportunity","unfamiliar","pathologists","operative","fluorescent","localized","assessment","technology","precision","intr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	narrowing
# 	unpenalized
# 	underscore
# 	timeliness
# 	thermodynamics
# 	deteriorates
# 	unavoidably
# 	exemplify
# 	confounders
# 	sectional
# 	dendrogram
# 	ultrametric
# 	indefinite
# 	collinearity
# 	uncollapsed
# 	homoscedastic
# 	downweighting
# 	equitability
# 	equitable
# 	expectimax
# Some words which never appear in Statistics papers:
# 	imprecision
# 	admissible
# 	kernelize
# 	observers
# 	histological
# 	unfamiliar
# 	operative
# 	fluorescent
# 	embracing
# 	enclosure
# 	deforming
# 	commercially
# 	compensation
# 	milliseconds
# 	untrimmed
# 	sentiments
# 	trafficking
# 	enforcement
# 	advertisement
# 	reflection

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0731407498463434e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
